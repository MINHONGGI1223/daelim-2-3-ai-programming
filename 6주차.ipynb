# %% [markdown]
# # 문자열 심화

# %% [markdown]
# ## 대소문자 변환

# %%
text='Hello Python'

print(text)

print(text.upper())
print(text.lower())

# %% [markdown]
# ## 공백 제거

# %%
name="            python          "

print(f"원본 {name}")
print(f"정리 후 {name.strip()}")

#변수와 String 비교
print("공백이 있을 때 비교",name=="python")
print("공백 제거 후 비교",name.strip()=="python")

# %% [markdown]
# ## 문자열 바꾸기

# %%
sentence="파이썬을 배우고 있습니다. 파이썬은 재밌습니다."

new_sentence=sentence.replace("파이썬","Python")

print("원본:",sentence)
print("수정:",new_sentence)

# %%
price="1,500,000원"
clean_price=price.replace(",","").replace("원","")

print(int(clean_price))

# %% [markdown]
# ## 문자열 나누기

# %%
words="사과 바나나 포도 딸기"

word_list=words.split()
print(word_list)

# %%
words="사과,바나나,포도,딸기"

word_list=words.split(",")
print(word_list,len (word_list))

# %% [markdown]
# ## 문자열 자르기

# %%
phone="010-1234-5678"

#앞에서 세글자
print(phone[0:3])
#가운데 네글자
print(phone[4:8])
#마지막 네글자
print(phone[-4:])

# %% [markdown]
# ## 문제
# 이메일 주소에서 아이디와 도메인을 분리하세요

# %%
email="12345@emali.dalim.ac.kr"

parts=email.split("@")
user_id=parts[0]
domain=parts[1]

print("이메일:",email)
print("아이디:",user_id)
print("도메인:",domain)

# %% [markdown]
# ## 문자열 검색

# %%
review="이 제품은 정말 좋아요! 배송도 빠르고 품질도 훌륭합니다"

print("좋아요 포함:","좋아요"in review)
print("나빠요 포함:","나빠요"in review)

if "좋아요" in review or "훌륭" in review:
    print("긍정적 리뷰")
else:
    print("부정적 리뷰")

# %% [markdown]
# ## 함수 심화

# %% [markdown]
# ## 함수 기본값

# %%
def greet(name, greeting="환영합니다"):
    print(f"{name}님, {greeting}")

greet("대림대")
greet("대림대","안녕하세요")

# %%
#할인율 계산
#discount: 0.0 ~ 1.0(0% ~ 100%)

def calcaulate_price(price,discount=0):
    discounted=price * (1-discount)
    return discounted

print(f"기본 가격: {calcaulate_price(10000)}원") 
print(f"기본 가격: {calcaulate_price(10000,0.1)}원")

# %% [markdown]
# ## 함수에서 여러값 반환하기

# %%
#최솟값과 최댓값을 동시에 반환하는 함수

def min_max(numbers):
    minimum=min(numbers)
    maximum=max(numbers)
    return minimum, maximum

scores=[10,20,30,40,50,60,70,80]

low,high=min_max(scores)

print(min_max(scores))
print("최솟값: ",low)
print("최대값: ",high)

# %% [markdown]
# ## 문제
# class_scores = [45,62,78,55,90,83,71,66,48,95]
# 1. 성적 분석 함수 생성
# 2. 아래아 같은 로그 출력
#     - 평균: x.x 점 (소수점 첫번째 자리 까지만 출력)
#     - 최고점: xx점
#     - 최저점: xx점
#     - 합격(60점 이상): x명

# %% [markdown]
# ## Pandas 심화

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

# %%
#학생 데이터
grade_data={
    "name":["kim","lee","park","choi","jung","min"],
    "korean":[88,72,95,65,80,91],
    "math":[75,90,65,85,77,82],
    "english":[82,88,76,70,95,78],
}
grade_df=pd.DataFrame(grade_data)
grade_df

# %% [markdown]
# ## 정렬하기

# %%
print("---국어 점수 낮은 순---")
print (grade_df.sort_values("korean"))
print()
print("---수학 점수 낮은 순---")
print (grade_df.sort_values("math",ascending=False))

# %% [markdown]
# ## 새로운 열 추가하기

# %%
grade_df["average"] = (grade_df["korean"] +  grade_df["math"] + grade_df["english"]) / 3

grade_df["average"]=grade_df["average"].round(1)
grade_df

# %%
grade_df["grade"]=grade_df["average"].apply{
    lambda x:"A" if x >= 80 else "B"
}

grade_df
# Out:
#   Cell In[88], line 1
#     grade_df["grade"]=grade_df["average"].apply{
#                                                ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 그룹별 통계

# %%
group_avg=grade_df.groupby("grade")["average"].mean()
print("등급별 평균:")
print(group_avg)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 group_avg=grade_df.groupby("grade")["average"].mean()
#       2 print("등급별 평균:")
#       3 print(group_avg)
#
# File d:\202530309\.venv\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File d:\202530309\.venv\Lib\site-packages\pandas\core\frame.py:10817, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10814 if level is None and by is None:
#   10815     raise TypeError("You have to supply one of 'by' and 'level'")
# > 10817 return DataFrameGroupBy(
#   10818     obj=self,
#   10819     keys=by,
#   10820     level=level,
#   10821     as_index=as_index,
#   10822     sort=sort,
#   10823     group_keys=group_keys,
#   10824     observed=observed,
#   10825     dropna=dropna,
#   10826 )
#
# File d:\202530309\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:1095, in GroupBy.__init__(self, obj, keys, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1092 self.dropna = dropna
#    1094 if grouper is None:
# -> 1095     grouper, exclusions, obj = get_grouper(
#    1096         obj,
#    1097         keys,
#    1098         level=level,
#    1099         sort=sort,
#    1100         observed=observed,
#    1101         dropna=self.dropna,
#    1102     )
#    1104 self.observed = observed
#    1105 self.obj = obj
#
# File d:\202530309\.venv\Lib\site-packages\pandas\core\groupby\grouper.py:901, in get_grouper(obj, key, level, sort, observed, validate, dropna)
#     899         in_axis, level, gpr = False, gpr, None
#     900     else:
# --> 901         raise KeyError(gpr)
#     902 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     903     # Add key to exclusions
#     904     exclusions.add(gpr.key)
#
# KeyError: 'grade'

# %%
#응용-회사 부서별 급여 파악
employee_data={
    "name":["kim","lee","park","choi","jung","min"],
    "department":["개발","마케팅","개발","인사","마케팅","인사"],
    "salary":[4200,3500,4800,3200,3800,5000],
} 
emp_df=pd.DataFrame(employee_data)
emp_df

#부서별 평균 급여
dept_avg=emp_df.groupby("department")["salary"].mean()
print("---부서별 평균 급여---")
print(dept_avg.round(0))
print()
print("---부서별 인원 수---")
dept_count=emp_df.groupby("department")["name"].count()
print(dept_count)
# Out:
# ---부서별 평균 급여---
# department
# 개발     4500.0
# 마케팅    3650.0
# 인사     4100.0
# Name: salary, dtype: float64
#
# ---부서별 인원 수---
# department
# 개발     2
# 마케팅    2
# 인사     2
# Name: name, dtype: int64
